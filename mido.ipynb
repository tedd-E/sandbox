# %%
from mido import MidiFile
import numpy as np 
from collections import defaultdict

def midi_to_note(note_number):
    note_names = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
    octave = note_number // 12 - 1
    return note_names[note_number % 12]
    

mid = MidiFile('bohemian_rhapsody.mid', clip=True)

tracks = []

for i, track in enumerate(mid.tracks):
    curr_track = defaultdict(int)
    for msg in track:
        if msg.type == 'note_on':
            note = msg.note
            velocity = msg.velocity
            timestamp = msg.time
            curr_track[midi_to_note(note)] += 1
            
        tracks.append(curr_track)

# %%
tracks
# Out:
# [defaultdict(int, {}),
#  defaultdict(int, {}),
#  defaultdict(int, {}),
#  defaultdict(int, {}),
#  defaultdict(int, {}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
#               'F#': 4,
#               'B': 6,
#               'E': 8}),
#  defaultdict(int,
#              {'C': 17,
#               'D': 16,
#               'A#': 14,
#               'C#': 5,
#               'D#': 18,
#               'F': 18,
#               'G#': 10,
#               'A': 5,
#               'G': 21,
# ...
#               'A#': 27,
#               'C': 12,
#               'D#': 9,
#               'F': 26,
#               'G': 30,
#               'G#': 2,
#               'A': 11,
#               'E': 3,
#               'B': 1,
#               'F#': 2}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  defaultdict(int,
#              {'A#': 252,
#               'F': 278,
#               'C#': 66,
#               'G#': 79,
#               'B': 79,
#               'F#': 44,
#               'D#': 163,
#               'C': 303,
#               'D': 166,
#               'A': 134,
#               'E': 113,
#               'G': 243}),
#  ...]
